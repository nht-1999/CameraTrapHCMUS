# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or yolov5m, yolov5l, yolov5x, custom

# Images
img = 'https://ultralytics.com/images/zidane.jpg'  # or file, Path, PIL, OpenCV, numpy, list

# Inference
results = model(img)

# Results
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
# Out:
# Using cache found in /Users/mtosity/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2021-10-1 torch 1.9.1 CPU
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# Adding AutoShape...
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 1126.2ms pre-process, 215.9ms inference, 1.8ms NMS per image at shape (1, 3, 384, 640)

# %%
# !git clone https://github.com/ultralytics/JSON2YOLO
# Out:
# Cloning into 'JSON2YOLO'...
# remote: Enumerating objects: 258, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 258 (delta 48), reused 51 (delta 19), pack-reused 172
# Receiving objects: 100% (258/258), 66.88 KiB | 1.22 MiB/s, done.
# Resolving deltas: 100% (160/160), done.

# %%
# !ls
# Out:
# LICENSE               ena24.json            wandb
# README.md             general_json2yolo.py  yolo_debug.ipynb
# __pycache__           labelbox_json2yolo.py yolov5
# dataset.yaml          requirements.txt      yolov5s.pt
# datasets              utils.py

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9428, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9428 (delta 1), reused 4 (delta 0), pack-reused 9422
# Receiving objects: 100% (9428/9428), 9.90 MiB | 5.05 MiB/s, done.
# Resolving deltas: 100% (6544/6544), done.

# %%
# !python general_json2yolo.py
# Out:
# COCO
# ./
# [PosixPath('/Users/mtosity/projects/iwildcam-kltn/yolo/ena24.json')]
# <class 'dict'>
# Annotations /Users/mtosity/projects/iwildcam-kltn/yolo/ena24.json: 100%|█| 11596

# %%
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 2.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 180 kB 7.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 139 kB 7.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 6.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 2.9 MB/s eta 0:00:011
# ...
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21502 sha256=a7d35b1ea077230b7e32bf46367a7719f475e09d07fe1ddd03330df8a7d8a42e
#   Stored in directory: /Users/mtosity/Library/Caches/pip/wheels/54/aa/01/724885182f93150035a2a91bce34a12877e8067a97baaf5dc8
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=57560219db6bb3cdd806d305e9a698065ca89ef9662078fa55dfc861c28ff5ae
#   Stored in directory: /Users/mtosity/Library/Caches/pip/wheels/9f/69/d1/50b39b308a87998eaf5c1d9095e5a5bd2ad98501e2b7936d36
# ...

# %%
# !python yolov5/train.py --img 640 --batch 16 --epochs 3 --data dataset.yaml --weights yolov5s.pt
# Out:
# wandb: Currently logged in as: mtosity (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=yolov5/data/hyps/hyp.scratch.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, entity=None, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=100
# ^C
# github: Traceback (most recent call last):
#   File "yolov5/train.py", line 616, in <module>
#     main(opt)
#   File "yolov5/train.py", line 479, in main
#     check_git_status()
#   File "/Users/mtosity/projects/iwildcam-kltn/yolo/yolov5/utils/general.py", line 78, in handler
#     func(*args, **kwargs)
# ...

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp10/weights/best.pt --img 640 --conf 0.25 --source datasets/ena24-splitted/test/images
# Out:
# detect: weights=['yolov5/runs/train/exp10/weights/best.pt'], source=datasets/ena24-splitted/test/images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-492-gb0ade48 torch 1.9.1 CPU
#
# Fusing layers...
# Model Summary: 224 layers, 7113244 parameters, 0 gradients, 16.5 GFLOPs
# image 1/1176 /Users/mtosity/projects/iwildcam-kltn/yolo/datasets/ena24-splitted/test/images/8501.jpg: 384x640 2 American Crows, Done. (0.205s)
# image 2/1176 /Users/mtosity/projects/iwildcam-kltn/yolo/datasets/ena24-splitted/test/images/8502.jpg: 384x640 2 American Crows, Done. (0.193s)
# ...

# %%
# !python yolov5/train.py --img 640 --batch 16 --data datasets/vehicles-data-yolo/data.yaml --weights yolov5/runs/train/exp17/weights/best.pt
# Out:
# wandb: Currently logged in as: mtosity (use `wandb login --relogin` to force relogin)
# train: weights=yolov5/runs/train/exp17/weights/best.pt, cfg=, data=datasets/vehicles-data-yolo/data.yaml, hyp=yolov5/data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, entity=None, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=100
# github: up to date with https://github.com/ultralytics/JSON2YOLO ✅
# YOLOv5 🚀 v5.0-492-gb0ade48 torch 1.9.1 CPU
#
# ...
